# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Read an image
# image = cv2.imread('../images/5.2.09.jpg')
image = cv2.imread('../images/5.3.01.jpg')

# %%
image.shape
# Out:
# (1024, 1024, 3)

# %%
# Apply log transformation method   
c = 255 / np.log(1 + np.max(image))
log_image = c * np.log(1 + image)

# Specify the data type so that float value will be converted to int
log_image = np.array(log_image, dtype = np.uint8)

# Display both images
plt.imshow(image)
plt.show()
plt.imshow(log_image);

# %%
cv2.imwrite('log_image.jpg', log_image)
# Out:
# True

# %% [markdown]
# Relevant links:
#
# MUST READ: https://qr.ae/pvaat2
#
# Also Good: https://theailearner.com/2019/01/01/log-transformation/
#
# https://www.tutorialspoint.com/dip/gray_level_transformations.htm
#
# https://www.geeksforgeeks.org/log-transformation-of-an-image-using-python-and-opencv/#:~:text=Log%20transformation%20of%20an%20image%20means%20replacing%20all%20pixel%20values,compared%20to%20higher%20pixel%20values.
